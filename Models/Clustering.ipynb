# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import kagglegym

# %%
with pd.HDFStore("../input/train.h5", "r") as train:
    # Note that the "train" dataframe is the only dataframe in the file
    df = train.get("train")

# %%
from sklearn import linear_model
ids = df['id'].unique()
beta_mat = zeros((len(ids), 108))

for i in range(len(ids)):
    # print(i)
    data = df[df['id'] == ids[i]]
    mean_vals = data.mean()
    data = data.fillna(mean_vals)
    data = data.fillna(0.0)
#     data = data.dropna(axis=1,how='any')
    
    # Find the columns with the most correlation with y
#     corr_mat[ids[i]] = np.array(data.corr(method='pearson', min_periods=1))[:,len(data.columns) - 1]
    model = linear_model.LinearRegression()
    test_x = np.array(data)[:,2:-1]
    test_y = np.array(data)[:,-1]
    length = len(test_x[:,0])
    width = len(test_x[0,:])
#     print(shape(test_y))
    model.fit(test_x.reshape(length, width), test_y.reshape(length,1))
    beta_mat[i,:] = array(model.coef_)

# %%
from sklearn.cluster import KMeans
kmean = KMeans(n_clusters=3).fit(array(beta_mat))

# %%
kmean.cluster_centers_
# Out:
# array([[ -2.27243113e+01,   3.15884734e+00,   1.67635489e+01,
#          -7.76274360e+00,  -4.24741989e+00,   3.12706996e+00,
#          -3.00774826e-01,  -1.89719880e+01,   1.32046928e+01,
#          -2.65111672e+00,  -1.28337085e+00,   7.30120562e+00,
#          -1.14935021e+01,   9.95575819e+00,   1.54756424e+01,
#           2.38542479e+01,   3.08805091e-01,  -2.25548433e+00,
#           4.19068169e+00,  -7.93961476e-01,   8.88184442e+00,
#           3.46300524e+00,  -1.62794008e+01,   1.95238548e+01,
#           6.48223828e+00,  -2.33322716e+01,  -2.96877056e+00,
#          -2.27900090e+01,  -7.46371457e+00,  -9.79422720e-01,
#          -4.94871735e+00,  -1.69201326e+01,   2.41673575e+00,
#          -2.84968772e+00,   1.74071583e+00,  -1.26773341e+01,
#          -4.43039956e+00,   1.33756213e+00,   1.26721923e+01,
#           2.35305417e+00,   6.54500089e+00,  -1.15515949e+01,
#          -9.63706677e-01,  -1.01531618e+00,   6.55111770e+00,
#           1.97846026e+00,  -2.33737653e+01,  -1.64750149e+01,
#           1.85245560e+01,  -2.76906812e+00,   9.58384433e+00,
#           5.71388351e+00,  -1.99474766e+00,   8.69275856e+00,
#           8.19909069e+00,  -1.75319783e+00,  -1.55587661e+01,
#           4.27200442e+00,   1.88508727e+01,  -1.02346009e+01,
#          -2.73518804e-01,  -3.39783488e+00,  -4.92759007e+00,
#          -7.95232710e+00,  -1.01315569e+01,   5.31652705e+00,
#          -1.99848083e+01,   1.52429437e-01,   6.74254193e+00,
#           9.71443036e-05,  -9.80264132e+00,  -2.03133085e-03,
#          -1.68828970e-02,  -9.74796861e+00,   2.88359511e-01,
#          -4.85023851e-01,  -3.46809522e+00,  -1.76952587e+00,
#           5.57096588e+00,  -1.23773570e+00,  -3.37187648e+00,
#           1.41290363e+00,   2.78960960e+00,  -4.72556496e-01,
#           2.52255983e+01,  -2.02497545e+00,   1.45956959e+00,
#           1.36043654e-03,   2.19639393e-04,  -1.42656973e-02,
#          -5.00099403e+01,  -1.04301885e-02,  -4.69322610e+00,
#           1.86318300e+00,   1.26344227e-03,  -1.48003255e+00,
#           2.06413291e-02,  -1.66947702e-03,  -8.21935193e+00,
#           2.02368338e+01,  -4.26427956e+00,   4.27856986e+00,
